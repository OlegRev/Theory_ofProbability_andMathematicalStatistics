# %%
import numpy as np
import pandas as pd
import scipy.stats

# %% [markdown]
# ### 1) Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks):
#
#     zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110],
#     ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832].
#
# Найдите ковариацию этих двух величин с помощью элементарных действий,
# а затем с помощью функции cov из numpy
# Полученные значения должны быть равны.
#
# Найдите коэффициент корреляции Пирсона с помощью ковариации
# и среднеквадратичных отклонений двух признаков,
#
# а затем с использованием функций из библиотек numpy и pandas.
#
# Формула для вычисления ковариации:
#
# $$cov_{XY} = M(XY) - M(X)M(Y)$$
# Формула для вычисления коэффициента корреляции Пирсона:
# $$r_{XY} = \frac{cov_{XY}}{\sigma_{X}\sigma_{Y}}$$

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
df = pd.DataFrame({'zp': zp, 'ks': ks}, columns=['zp', 'ks'])


zp_ks = zp*ks
cov_XY = zp_ks.mean() - zp.mean()*ks.mean()
D_zp = zp.var()
𝜎_zp = np.sqrt(D_zp)
D_ks = ks.var()
𝜎_ks = np.sqrt(D_ks)
r_XY = cov_XY/(𝜎_zp*𝜎_ks)

np_cov_XY = np.cov(zp,ks,ddof=0)[0, 1]
std_zp = zp.std()
std_ks = ks.std()
np_r_XY = np_cov_XY/(std_zp*std_ks)

pd_cov_XY = df.cov().values[0, 1]
pd_r_XY = df.corr()
print(f'𝑐𝑜𝑣𝑋𝑌 = 𝑀(𝑋𝑌)−𝑀(𝑋)𝑀(𝑌) : {cov_XY},\n'
      f'np.cov(zp,ks,ddof=0)[0, 1] : {np_cov_XY}\n\n'
      f'round(𝑐𝑜𝑣𝑋𝑌, 2)==round(np_cov_XY, 2) :'
      f' {round(cov_XY, 2)==round(np_cov_XY, 2)}\n'
      f'коэффициент корреляции Пирсона с помощью ковариации \n'
      f'и среднеквадратичных отклонений двух признаков : {r_XY}\n'
      f'с использованием функций из библиотек numpy :'
      f' {np.cov(zp,ks,ddof=0)[0, 1]/ (std_zp*std_ks)}\n'
      f'и pandas :\n {pd_r_XY}')
# Out:
# 𝑐𝑜𝑣𝑋𝑌 = 𝑀(𝑋𝑌)−𝑀(𝑋)𝑀(𝑌) : 9157.839999999997,
# np.cov(zp,ks,ddof=0)[0, 1] : 9157.840000000002
#
# round(𝑐𝑜𝑣𝑋𝑌, 2)==round(np_cov_XY, 2) : True
# коэффициент корреляции Пирсона с помощью ковариации
# и среднеквадратичных отклонений двух признаков : 0.8874900920739158
# с использованием функций из библиотек numpy : 0.8874900920739163
# и pandas :
#           zp       ks
# zp  1.00000  0.88749
# ks  0.88749  1.00000

# %% [markdown]
# ### 2) Измерены значения IQ выборки студентов, обучающихся в местных технических вузах:
#
#     131, 125, 115, 122, 131, 115, 107, 99, 125, 111.
#
# Известно, что в генеральной совокупности IQ распределен нормально.
#
# Найдите доверительный интервал для математического ожидания с надежностью 0.95.
#
# $$\alpha=0.05\quad \frac{\alpha}{2} = 0.025$$

# %%
IQ = np.array([131, 125, 115, 122, 131, 115, 107, 99, 125, 111])
n = len(IQ)
M_IQ = IQ.mean()
𝛼 = 0.05
𝛼_divided_by_2 = 𝛼/2
degree_of_freedom = n - 1
t_Student = scipy.stats.t.ppf(1-𝛼_divided_by_2, degree_of_freedom)


M_minus = M_IQ - (t_Student * IQ.std(ddof=1))/np.sqrt(n)
M_plus = M_IQ + (t_Student * IQ.std(ddof=1))/np.sqrt(n)

print(f'Значения IQ выборки студентов: {IQ}\n'
      f'Велечина выборки: {n}\n'
      f'M(IQ) = {M_IQ}\n'
      f'Надежностью = 0.95, 𝛼 = {𝛼}, 𝛼/2 = {𝛼_divided_by_2}\n'
      f'Степень свободы : {degree_of_freedom}\n'
      f't критерий Стьюдента : {t_Student}\n'
      f'Доверительный интервал для математического ожидания\n'
      f' с надежностью 0.95 : [{M_minus}, {M_plus}]')
# Out:
# Значения IQ выборки студентов: [131 125 115 122 131 115 107  99 125 111]
# Велечина выборки: 10
# M(IQ) = 118.1
# Надежностью = 0.95, 𝛼 = 0.05, 𝛼/2 = 0.025
# Степень свободы : 9
# t критерий Стьюдента : 2.2621571627409915
# Доверительный интервал для математического ожидания
#  с надежностью 0.95 : [110.55608365158724, 125.64391634841274]

# %% [markdown]
# ### 3) Известно, что рост футболистов в сборной распределен нормально
# с дисперсией генеральной совокупности, равной 25 кв.см. Объем выборки равен 27,
# среднее выборочное составляет 174.2. Найдите доверительный интервал для математического
# ожидания с надежностью 0.95.

# %%
D = 25
𝜎 = np.sqrt(D)
n = 27
M = 174.2
𝛼 = 0.05
𝛼_divided_by_2 = 𝛼/2

z_t = 1.96
M_minus = M - (z_t * 𝜎)/np.sqrt(n)
M_plus = M + (z_t * 𝜎)/np.sqrt(n)

print(f'Велечина выборки: {n}\n'
      f'Среднее выборочное составляет : {M}\n'
      f'дисперсией генеральной совокупности, равной {D} кв.см \n'
      f'𝜎 = {𝜎}\n'
      f'Надежностью = 0.95, 𝛼 = {𝛼}, 𝛼/2 = {𝛼_divided_by_2}\n'
      f'Z критерий : {z_t}\n'
      f'Доверительный интервал для математического ожидания\n'
      f' с надежностью 0.95 : [{M_minus}, {M_plus}]')
# Out:
# Велечина выборки: 27
# Среднее выборочное составляет : 174.2
# дисперсией генеральной совокупности, равной 25 кв.см
# 𝜎 = 5.0
# Надежностью = 0.95, 𝛼 = 0.05, 𝛼/2 = 0.025
# Z критерий : 1.96
# Доверительный интервал для математического ожидания
#  с надежностью 0.95 : [172.31398912064722, 176.08601087935276]
